# %%
# !python main_NoGE.py \
    --dataset type_aptnotes \
    --num_iterations 3000 \
    --eval_after 2000 \
    --batch_size 1024 \
    --lr 1e-6 \
    --emb_dim 200 \
    --hidden_dim 200 \
    --encoder QGNN \
    --variant D \
    --semantic_type None \
    --pretrain_dir ./cybert
# Out:
# device: cuda
# Number of training data points: 3798
# Creating the new weighted Adj matrix!
# dat_values: 10928
# len of adj: 1475
# Training with the GAT encoder
# Using Adam optimizer
# Starting training...
# Epoch: 1  --> Loss: 0.2982
# Epoch: 2  --> Loss: 0.3012
# Epoch: 3  --> Loss: 0.2968
# Epoch: 4  --> Loss: 0.2863
# Epoch: 5  --> Loss: 0.3015
# Epoch: 6  --> Loss: 0.2981
# Epoch: 7  --> Loss: 0.2834
# Epoch: 8  --> Loss: 0.2938
# Epoch: 9  --> Loss: 0.3111
# Epoch: 10  --> Loss: 0.2896
# Epoch: 11  --> Loss: 0.2967
# Epoch: 12  --> Loss: 0.2905
# Epoch: 13  --> Loss: 0.3005
# Epoch: 14  --> Loss: 0.2906
# Epoch: 15  --> Loss: 0.2891
# Epoch: 16  --> Loss: 0.2898
# Epoch: 17  --> Loss: 0.3054
# Epoch: 18  --> Loss: 0.2820
# Epoch: 19  --> Loss: 0.2947
# Epoch: 20  --> Loss: 0.3002
# Epoch: 21  --> Loss: 0.2943
# Epoch: 22  --> Loss: 0.3095
# Epoch: 23  --> Loss: 0.3096
# Epoch: 24  --> Loss: 0.3041
# Epoch: 25  --> Loss: 0.2875
# Epoch: 26  --> Loss: 0.2997
# ...

# %%
python main_NoGE.py --dataset type_aptnotes --num_iterations 3000 --eval_after 2000 --batch_size 1024 --lr 1e-6 --emb_dim 200 --hidden_dim 200 --encoder QGNN --variant D --semantic_type None --pretrain_dir ./cybert
